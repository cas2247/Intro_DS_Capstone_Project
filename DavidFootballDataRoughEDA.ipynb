# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

football_data = pd.read_excel("Final.xlsx")
football_data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1           Player  ...    Att  Succ%    #Pl
# 0           0             0    Kylian Mbappé  ...  247.0  53.44  152.0
# 1           1             1  Raheem Sterling  ...  258.0  53.88  151.0
# 2           2             2           Neymar  ...  292.0  56.16  184.0
# 3           3             3       Sadio Mané  ...  212.0  60.38  142.0
# 4           4             4    Mohamed Salah  ...  229.0  59.83  148.0
#
# [5 rows x 52 columns]

# %%
football_data = football_data.drop(["Unnamed: 0", "Unnamed: 0.1"],axis='columns')
football_data.head()
# Out:
#             Player Market value Nation    Pos  ... Succ_y    Att  Succ%    #Pl
# 0    Kylian Mbappé     €180.00m    FRA     FW  ...  132.0  247.0  53.44  152.0
# 1  Raheem Sterling     €128.00m    ENG     FW  ...  139.0  258.0  53.88  151.0
# 2           Neymar     €128.00m    BRA  MF,FW  ...  164.0  292.0  56.16  184.0
# 3       Sadio Mané     €120.00m    SEN     FW  ...  128.0  212.0  60.38  142.0
# 4    Mohamed Salah     €120.00m    EGY     FW  ...  137.0  229.0  59.83  148.0
#
# [5 rows x 50 columns]

# %%
football_data = football_data.rename({"Leauge": "League"}, axis='columns')

# %%
football_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 50 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Player            517 non-null    object
#  1   Market value      517 non-null    object
#  2   Nation            370 non-null    object
#  3   Pos               370 non-null    object
#  4   Club_x            370 non-null    object
#  5   Leauge            370 non-null    object
#  6   Age               363 non-null    float64
#  7   MP                356 non-null    float64
#  8   Starts            356 non-null    float64
#  9   Min               356 non-null    float64
#  10  Gls               356 non-null    float64
#  11  Ast               356 non-null    float64
#  12  PK_x              356 non-null    float64
#  13  PKatt_x           356 non-null    float64
#  14  CrdY              356 non-null    float64
#  15  CrdR              356 non-null    float64
#  16  Gls90             356 non-null    float64
#  17  Ast90             356 non-null    float64
#  18  G+A               356 non-null    float64
#  19  Gls+Ast           356 non-null    float64
#  20  PK                363 non-null    float64
#  21  PKatt             363 non-null    float64
#  22  Sh                356 non-null    float64
#  23  SoT               356 non-null    float64
#  24  FK                363 non-null    float64
#  25  SoT%              356 non-null    float64
#  26  Sh/90             356 non-null    float64
#  27  SoT/90            356 non-null    float64
#  28  G/Sh              356 non-null    float64
#  29  G/SoT             356 non-null    float64
#  30  Tackle            356 non-null    float64
#  31  TackleW           356 non-null    float64
#  32  TakleD            357 non-null    float64
#  33  Tkl%              363 non-null    float64
#  34  Press             356 non-null    float64
#  35  Succ_x            356 non-null    float64
#  36  %                 356 non-null    float64
#  37  Blocks            356 non-null    float64
#  38  ShotB             356 non-null    float64
#  39  PassB             356 non-null    float64
#  40  Int               356 non-null    float64
#  41  Clr               356 non-null    float64
#  42  Passes Completed  356 non-null    float64
#  43  Passes Attempted  356 non-null    float64
#  44  Cmp%              356 non-null    float64
#  45  Touches           356 non-null    float64
#  46  Succ_y            356 non-null    float64
#  47  Att               356 non-null    float64
#  48  Succ%             356 non-null    float64
#  49  #Pl               357 non-null    float64
# dtypes: float64(44), object(6)
# memory usage: 202.1+ KB

# %%
## Get a sense of how market value is represented in the data

football_data["Market value"].value_counts()
# Out:
# €20.00m     60
# €32.00m     39
# €16.00m     38
# €24.00m     37
# €28.00m     34
# €17.50m     32
# €40.00m     30
# €22.50m     29
# €48.00m     19
# €18.00m     17
# €36.00m     16
# €56.00m     12
# €25.50m     11
# €64.00m     10
# €19.00m      9
# €72.00m      8
# €31.50m      8
# €52.00m      7
# €80.00m      7
# €45.00m      6
# €44.00m      6
# €18.50m      5
# €60.00m      5
# €25.00m      5
# €27.00m      5
# €30.50m      5
# €120.00m     4
# €21.50m      4
# €22.00m      4
# €17.00m      3
# €30.00m      3
# €68.00m      3
# €35.00m      3
# €54.00m      3
# €49.50m      3
# €40.50m      3
# €33.50m      2
# €29.00m      2
# €81.00m      2
# €128.00m     2
# €24.50m      2
# €33.00m      1
# €21.00m      1
# €65.00m      1
# €117.00m     1
# €50.00m      1
# €112.00m     1
# €23.00m      1
# €75.00m      1
# €99.00m      1
# €67.50m      1
# €96.00m      1
# €37.50m      1
# €29.50m      1
# €180.00m     1
# Name: Market value, dtype: int64

# %%
## Convert the Market Value column into int with vectorized string cleaning and type conversion

def euros_to_num(euro_string):
    euro_string = euro_string.replace("€", "")
    num_string = euro_string.split(".")[0] + euro_string.split(".")[1][:2]
    num_string += 4*"0"
    return num_string

football_data["Market value"] = football_data["Market value"].map(euros_to_num).astype(int)

# %%
football_data["Market value"].describe()
# Out:
# count    5.170000e+02
# mean     3.305706e+07
# std      2.015584e+07
# min      1.600000e+07
# 25%      2.000000e+07
# 50%      2.700000e+07
# 75%      4.000000e+07
# max      1.800000e+08
# Name: Market value, dtype: float64

# %%
plt.figure(figsize=(16,10))

plt.title("Distribution of Market Value", fontdict={'fontsize': 16})

sns.histplot(football_data["Market value"])

plt.show()

# %%
# %matplotlib inline

plt.figure(figsize=(40,10))

sns.swarmplot(x=football_data["Nation"],y=football_data["Market value"])
plt.title("Market Value of Players by Nation", fontdict={'fontsize': 26})

plt.show()

# %%
plt.figure(figsize=(20,10))

sns.regplot(x=football_data["Gls"], y=football_data["Market value"])

plt.title("Relationship between Goals and Market Value", fontdict={'fontsize': 16})

plt.show()

# %%
plt.figure(figsize=(20,10))

sns.swarmplot(x=football_data["League"],y=football_data["Market value"])
plt.title("Market Value of Players by League", fontdict={'fontsize': 16})

plt.show()

# %%
football_data[["Pos_1", "Pos_2"]] = football_data["Pos"].str.split(",", expand=True)
football_data[["Pos_1", "Pos_2"]]
# Out:
#     Pos_1 Pos_2
# 0      FW  None
# 1      FW  None
# 2      MF    FW
# 3      FW  None
# 4      FW  None
# ..    ...   ...
# 512    MF    FW
# 513    MF    FW
# 514    MF    FW
# 515    MF    FW
# 516    FW  None
#
# [517 rows x 2 columns]

# %%
plt.figure(figsize=(20,10))

sns.swarmplot(x=football_data["Pos_1"],y=football_data["Market value"])
plt.title("Market Value of Players by Primary Position", fontdict={'fontsize': 16})

plt.show()

# %%
plt.figure(figsize=(20,10))

sns.swarmplot(x=football_data["Pos_2"],y=football_data["Market value"])
plt.title("Market Value of Players by Secondary Position", fontdict={'fontsize': 16})

plt.show()

# %%
plt.figure(figsize=(20,10))

plt.title("Relationship between Age and Market Value", fontdict={'fontsize': 16})

sns.regplot(x=football_data["Age"], y=football_data["Market value"])

plt.show()

# %%
plt.figure(figsize=(20, 10))

sns.lmplot(data=football_data, x="Age", y="Market value", hue="Pos_1", height=8)

plt.title("Relationship between Age and Market Value by Position", fontdict={'fontsize': 12})

plt.show()
